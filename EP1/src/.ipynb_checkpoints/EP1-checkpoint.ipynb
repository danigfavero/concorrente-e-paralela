# %% [markdown]
# # EP1 - Cálculo do Conjunto de Mandelbrot em Paralelo com Pthreads e OpenMP
#
# 25 de Maio de 2020
#
# ## Membros do grupo
#
# | Nome | NUSP |
# |------|------|
# | Carolina Marques | 10737101 |
# | Daniela Favero | 10277443 |
# | Miguel Ostrowski | 10723610 |
# | Raphael Ribeiro | 10281601 |
#
# ## Pacotes Julia
#
# Instalando os pacotes necessários que estão listados no arquivo `Project.toml`:

# %%
] up
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %Fetching: [=======>                                 ]  16.2 %                           ]  30.1 % [==================>                      ]  44.1 %58.0 %=============================>           ]  72.0 %Fetching: [=============================>           ]  72.3 %>     ]  86.2 %Fetching: [=======================================> ]  97.1 % Resolving package versions...
#  Installed Zlib_jll ────────── v1.2.11+10
#  Installed ZeroMQ_jll ──────── v4.3.2+3
#  Installed CategoricalArrays ─ v0.8.1
#  Installed Plots ───────────── v1.3.1
#   Updating `~/Documents/julia/concorrente-e-paralela/EP1/src/Project.toml`
#  [no changes]
#   Updating `~/Documents/julia/concorrente-e-paralela/EP1/src/Manifest.toml`
#   [324d7699] ↑ CategoricalArrays v0.8.0 ⇒ v0.8.1
#   [91a5bcdd] ↑ Plots v1.2.6 ⇒ v1.3.1
#   [8f1865be] ↑ ZeroMQ_jll v4.3.2+2 ⇒ v4.3.2+3
#   [83775a58] ↑ Zlib_jll v1.2.11+9 ⇒ v1.2.11+10
#   Building Plots → `~/.julia/packages/Plots/lIZ4V/deps/build.log`

# %% [markdown]
# Verificando o status dos pacotes:

# %%
] st
# Out:
#     Status `~/Documents/julia/concorrente-e-paralela/EP1/src/Project.toml`
#   [336ed68f] CSV v0.6.2
#   [a93c6f00] DataFrames v0.21.0
#   [31c24e10] Distributions v0.23.2
#   [7073ff75] IJulia v1.21.2
#   [8314cec4] PGFPlotsX v1.2.6
#   [1a8c2f83] Query v0.12.2
#   [f3b207a7] StatsPlots v0.14.6

# %% [markdown]
# ## Compilando
#
# Compilando e executando os códigos C pelo *modo shell*:

# %%
; make
# Out:
# gcc -Wall -o mandelbrot_seq mandelbrot_seq.c
# gcc -pthread -Wall -o mandelbrot_pth mandelbrot_pth.c
# gcc -fopenmp -Wall -o mandelbrot_omp mandelbrot_omp.c

# %%
; ./mandelbrot_seq -2.5 1.5 -2.0 2.0 11500 1
# Out:
# 20.898508

# %% [markdown]
# Além de imprimir o tempo levado, o programa em C gera a seguinte imagem (gerada no formato ppm, tomamos liberdade para convertê-la para png e exibir aqui):
#
# <img src="output.png" alt="mandelbrot_seq" width="400"/>

# %%
; ./mandelbrot_pth -2.5 1.5 -2.0 2.0 11500 4
# Out:
# 11.562587

# %% [markdown]
# Imagem gerada, novamente a Full Screen, dessa vez usando 4 threads com auxílio de PThreads:
#
# <img src="output_pth.png" alt="mandelbrot_pth" width="400"/>

# %%
; ./mandelbrot_omp -2.5 1.5 -2.0 2.0 11500 4
# Out:
# 7.660517

# %% [markdown]
# A mesma imagem, agora gerada usando OpenMP:
#
# <img src="output_omp.png" alt="mandelbrot_omp" width="400"/>
#
# OBS.: o processador do computador utilizado para rodar os experimentos possui 8 núcleos.

# %% [markdown]
# ## Experimentos
#
# ### Funções úteis
#
# A função abaixo recebe parâmetros `size`, com tamanho da imagem, `file`, com o nome do programa a ser executado e `threads`, com o número de threads do programa paralelo. A função executa o programa `file` com os parâmetros dados e devolve um `DataFrame` com os resultados.

# %%
using DataFrames, Query, StatsPlots, Statistics

function measure_mandelbrot(size, file, threads)
    results = parse.(Float64,
        split(chomp(read(`./$file -2.5 1.5 -2.0 2.0 $size $threads`, String)), ", "))
        
    return DataFrame(size = size,
        file = file,
        threads = threads,
        duration = results[1])
end
# Out:
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling Query [1a8c2f83-1ff3-5112-b086-8aa67b057ba1]
# └ @ Base loading.jl:1273
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1273
# measure_mandelbrot (generic function with 1 method)

# %% [markdown]
# A função `run_experiments` recebe os mesmos parâmetros `size`, `file`, e `threads`, e um parâmetro adicional `repetitions`, com o número de repetições de cada experimento com um dado número de `threads`. A função devolve um `DataFrame` com todos os experimentos.

# %%
function run_experiments(size, file, threads, repetitions)
    run(`make`)
    
    results = DataFrame(size = Int[],
        file = String[],
        threads = Int[],
        duration = Float64[])  
    
    for t in threads
        for s in size
            for r in 1:repetitions
                append!(results,
                    measure_mandelbrot(s, file, t))    
            end
        end
    end
    
    return results
end
# Out:
# run_experiments (generic function with 1 method)

# %% [markdown]
# A função `parse_results` recebe um `DataFrame` de resultados, e produzido pela função `run_experiments`. A função devolve um `DataFrame` com a média e o intervalo de confiança da média a 95% dos tempos de execução, agrupados por número de threads.

# %%
function parse_results_threads(results)
    parsed_results = results |>
                    @groupby(_.threads) |>
                    @map({threads = key(_),
                          mean_duration = mean(_.duration),
                          ci_duration = 1.96 * std(_.duration)}) |>
                    DataFrame
    
    return parsed_results
end
# Out:
# parse_results_threads (generic function with 1 method)

# %%
function parse_results_sizes(results)
    parsed_results = results |>
                    @groupby(_.size) |>
                    @map({size = key(_),
                          mean_duration = mean(_.duration),
                          ci_duration = 1.96 * std(_.duration)}) |>
                    DataFrame
    
    return parsed_results
end
# Out:
# parse_results_sizes (generic function with 1 method)

# %% [markdown]
# A função `save_csv_results`recebe um `DataFrame` e um nome de arquivo, e escreve o `DataFrame` em disco, no formato `.csv`, com o nome passado no argumento. A função `read_csv_results` recebe um nome de arquivo e lê o arquivo correspondente, devolvendo um `DataFrame`.

# %%
using CSV

function save_csv_results(data_frame, file)
    CSV.write(file, data_frame)
end
# Out:
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1273
# save_csv_results (generic function with 1 method)

# %%
using CSV

function read_csv_results(file)
    return CSV.read(file)
end
# Out:
# read_csv_results (generic function with 1 method)

# %% [markdown]
# A função `plot_results_threads` faz dois tipos de gráfico: ela pode mostrar todos os resultados de um experimento, marcando pontos no plano cartesiano; e também pode mostrar o resultado dado pela média e traçar uma linha vertical delimitando o intervalo de confiança do conjunto de amostras recebido.

# %%
pgfplotsx()

function plot_results_thread(x, y, series_label; yerror = [], max_thread_power = 7)      
    if yerror != []
        p = scatter(x,
            y,
            xaxis = :log2,
            xlabel = "Threads",
            xticks = [2 ^ x for x in 0:max_thread_power],
            yerror = yerror,
            alpha = 0.6,
            labels = series_label,
            legend = :topright)
    else
        p = scatter(x,
            y,
            xaxis = :log2,
            xlabel = "Threads",
            xticks = [2 ^ x for x in 0:max_thread_power],
            alpha = 0.6,
            labels = series_label,
            legend = :topright)
    end
    return p
end
# Out:
# plot_results_thread (generic function with 1 method)

# %% [markdown]
# A função `plot_results_size` faz o mesmo que a função acima, porém com o tamanho da imagem no eixo x.

# %%
pgfplotsx()

function plot_results_size(x, y, series_label; yerror = [], min_size = 1500, max_size = 11500, step = 1000)      
    if yerror != []
        p = scatter(x,
            y,
            xlabel = "Sizes",
            xticks = [x for x in min_size:step:max_size],
            yerror = yerror,
            alpha = 0.6,
            labels = series_label,
            legend = :topright)
    else
        p = scatter(x,
            y,
            xlabel = "Sizes",
            xticks = [x for x in min_size:step:max_size],
            alpha = 0.6,
            labels = series_label,
            legend = :topright)
    end
    return p
end
# Out:
# plot_results_size (generic function with 1 method)

# %% [markdown]
# ### Sequencial
#
# Realizando os experimentos rodando a célula abaixo.

# %%
threads = 1
file = "mandelbrot_seq"
size = [x for x in 1500:1000:8500]
repetitions = 10

results = run_experiments(size, file, threads, repetitions)
parsed_results = parse_results_sizes(results)

save_csv_results(results, "results_seq.csv")
results_seq = read_csv_results("results_seq.csv")
# Out:
# make: Nothing to be done for 'all'.
# 80×4 DataFrame
# │ Row │ size  │ file           │ threads │ duration │
# │     │ Int64 │ String         │ Int64   │ Float64  │
# ├─────┼───────┼────────────────┼─────────┼──────────┤
# │ 1   │ 1500  │ mandelbrot_seq │ 1       │ 0.467174 │
# │ 2   │ 1500  │ mandelbrot_seq │ 1       │ 0.424342 │
# │ 3   │ 1500  │ mandelbrot_seq │ 1       │ 0.422643 │
# │ 4   │ 1500  │ mandelbrot_seq │ 1       │ 0.424224 │
# │ 5   │ 1500  │ mandelbrot_seq │ 1       │ 0.418194 │
# │ 6   │ 1500  │ mandelbrot_seq │ 1       │ 0.43682  │
# │ 7   │ 1500  │ mandelbrot_seq │ 1       │ 0.429947 │
# │ 8   │ 1500  │ mandelbrot_seq │ 1       │ 0.428449 │
# │ 9   │ 1500  │ mandelbrot_seq │ 1       │ 0.430389 │
# │ 10  │ 1500  │ mandelbrot_seq │ 1       │ 0.481826 │
# ⋮
# │ 70  │ 7500  │ mandelbrot_seq │ 1       │ 10.5376  │
# │ 71  │ 8500  │ mandelbrot_seq │ 1       │ 12.6535  │
# │ 72  │ 8500  │ mandelbrot_seq │ 1       │ 13.1309  │
# │ 73  │ 8500  │ mandelbrot_seq │ 1       │ 13.1493  │
# │ 74  │ 8500  │ mandelbrot_seq │ 1       │ 12.7542  │
# │ 75  │ 8500  │ mandelbrot_seq │ 1       │ 12.6455  │
# │ 76  │ 8500  │ mandelbrot_seq │ 1       │ 12.7055  │
# │ 77  │ 8500  │ mandelbrot_seq │ 1       │ 12.8157  │
# │ 78  │ 8500  │ mandelbrot_seq │ 1       │ 13.3689  │
# │ 79  │ 8500  │ mandelbrot_seq │ 1       │ 12.8175  │
# │ 80  │ 8500  │ mandelbrot_seq │ 1       │ 16.3148  │

# %% [markdown]
# Veja no gráfico:

# %%
plot_results_size(results.size,
    results.duration,    
    "Duration",
    min_size = 1500,
    max_size = 11500,
    step = 1000)

# %%
plot_results_size(parsed_results.size,
    parsed_results.mean_duration,    
    "Mean Duration + CI",
    yerror = parsed_results.ci_duration,
    min_size = 1500,
    max_size = 11500,
    step = 1000)

# %% [markdown]
# ### PThreads
# Realizando os experimentos rodando a célula abaixo, variando em número de threads.

# %%
size = 11500
file = "mandelbrot_pth"
threads = [2 ^ x for x in 0:7]
repetitions = 10

results = run_experiments(size, file, threads, repetitions)
parsed_results = parse_results_threads(results)

save_csv_results(results, "results_pth_t.csv")
results_pth_t = read_csv_results("results_pth_t.csv")
# Out:
# make: Nothing to be done for 'all'.
# 80×4 DataFrame
# │ Row │ size  │ file           │ threads │ duration │
# │     │ Int64 │ String         │ Int64   │ Float64  │
# ├─────┼───────┼────────────────┼─────────┼──────────┤
# │ 1   │ 11500 │ mandelbrot_pth │ 1       │ 21.4131  │
# │ 2   │ 11500 │ mandelbrot_pth │ 1       │ 19.9393  │
# │ 3   │ 11500 │ mandelbrot_pth │ 1       │ 20.2611  │
# │ 4   │ 11500 │ mandelbrot_pth │ 1       │ 19.7691  │
# │ 5   │ 11500 │ mandelbrot_pth │ 1       │ 19.9509  │
# │ 6   │ 11500 │ mandelbrot_pth │ 1       │ 20.3656  │
# │ 7   │ 11500 │ mandelbrot_pth │ 1       │ 20.3831  │
# │ 8   │ 11500 │ mandelbrot_pth │ 1       │ 19.9524  │
# │ 9   │ 11500 │ mandelbrot_pth │ 1       │ 20.879   │
# │ 10  │ 11500 │ mandelbrot_pth │ 1       │ 21.0362  │
# ⋮
# │ 70  │ 11500 │ mandelbrot_pth │ 64      │ 6.16344  │
# │ 71  │ 11500 │ mandelbrot_pth │ 128     │ 5.65724  │
# │ 72  │ 11500 │ mandelbrot_pth │ 128     │ 6.90789  │
# │ 73  │ 11500 │ mandelbrot_pth │ 128     │ 5.50633  │
# │ 74  │ 11500 │ mandelbrot_pth │ 128     │ 5.7471   │
# │ 75  │ 11500 │ mandelbrot_pth │ 128     │ 5.91318  │
# │ 76  │ 11500 │ mandelbrot_pth │ 128     │ 5.81647  │
# │ 77  │ 11500 │ mandelbrot_pth │ 128     │ 5.56931  │
# │ 78  │ 11500 │ mandelbrot_pth │ 128     │ 5.67     │
# │ 79  │ 11500 │ mandelbrot_pth │ 128     │ 5.86674  │
# │ 80  │ 11500 │ mandelbrot_pth │ 128     │ 5.69588  │

# %% [markdown]
# Veja no gráfico:

# %%
plot_results_thread(results.threads,
    results.duration,    
    "Duration",
    max_thread_power = 7)

# %%
plot_results_thread(parsed_results.threads,
    parsed_results.mean_duration,
    "Mean Duration + CI",
    yerror = parsed_results.ci_duration,
    max_thread_power = 7)

# %% [markdown]
# Agora variando no tamanho da imagem.

# %%
threads = 4
file = "mandelbrot_pth"
size = [x for x in 1500:1000:11500]
repetitions = 10

results = run_experiments(size, file, threads, repetitions)
parsed_results = parse_results_sizes(results)

save_csv_results(results, "results_pth_s.csv")
results_pth_s = read_csv_results("results_pth_s.csv")
# Out:
# make: Nothing to be done for 'all'.
# 110×4 DataFrame
# │ Row │ size  │ file           │ threads │ duration │
# │     │ Int64 │ String         │ Int64   │ Float64  │
# ├─────┼───────┼────────────────┼─────────┼──────────┤
# │ 1   │ 1500  │ mandelbrot_pth │ 4       │ 0.224727 │
# │ 2   │ 1500  │ mandelbrot_pth │ 4       │ 0.216022 │
# │ 3   │ 1500  │ mandelbrot_pth │ 4       │ 0.210706 │
# │ 4   │ 1500  │ mandelbrot_pth │ 4       │ 0.188461 │
# │ 5   │ 1500  │ mandelbrot_pth │ 4       │ 0.185316 │
# │ 6   │ 1500  │ mandelbrot_pth │ 4       │ 0.185389 │
# │ 7   │ 1500  │ mandelbrot_pth │ 4       │ 0.181157 │
# │ 8   │ 1500  │ mandelbrot_pth │ 4       │ 0.18479  │
# │ 9   │ 1500  │ mandelbrot_pth │ 4       │ 0.179575 │
# │ 10  │ 1500  │ mandelbrot_pth │ 4       │ 0.179547 │
# ⋮
# │ 100 │ 10500 │ mandelbrot_pth │ 4       │ 8.89486  │
# │ 101 │ 11500 │ mandelbrot_pth │ 4       │ 13.2031  │
# │ 102 │ 11500 │ mandelbrot_pth │ 4       │ 11.4361  │
# │ 103 │ 11500 │ mandelbrot_pth │ 4       │ 11.1169  │
# │ 104 │ 11500 │ mandelbrot_pth │ 4       │ 11.0513  │
# │ 105 │ 11500 │ mandelbrot_pth │ 4       │ 10.9751  │
# │ 106 │ 11500 │ mandelbrot_pth │ 4       │ 11.4523  │
# │ 107 │ 11500 │ mandelbrot_pth │ 4       │ 10.8035  │
# │ 108 │ 11500 │ mandelbrot_pth │ 4       │ 11.1777  │
# │ 109 │ 11500 │ mandelbrot_pth │ 4       │ 13.5291  │
# │ 110 │ 11500 │ mandelbrot_pth │ 4       │ 10.8165  │

# %% [markdown]
# Veja no gráfico:

# %%
plot_results_size(results.size,
    results.duration,    
    "Duration",
    min_size = 1500,
    max_size = 11500,
    step = 1000)

# %%
plot_results_size(parsed_results.size,
    parsed_results.mean_duration,    
    "Mean Duration + CI",
    yerror = parsed_results.ci_duration,
    min_size = 1500,
    max_size = 11500,
    step = 1000)

# %% [markdown]
# ### OpenMP
# Realizando os experimentos rodando a célula abaixo, variando em número de threads.

# %%
size = 11500
file = "mandelbrot_omp"
threads = [2 ^ x for x in 0:7]
repetitions = 10

results = run_experiments(size, file, threads, repetitions)
parsed_results = parse_results_threads(results)

save_csv_results(results, "results_omp_t.csv")
results_omp_t = read_csv_results("results_omp_t.csv")
# Out:
# make: Nothing to be done for 'all'.
# 80×4 DataFrame
# │ Row │ size  │ file           │ threads │ duration │
# │     │ Int64 │ String         │ Int64   │ Float64  │
# ├─────┼───────┼────────────────┼─────────┼──────────┤
# │ 1   │ 11500 │ mandelbrot_omp │ 1       │ 19.3667  │
# │ 2   │ 11500 │ mandelbrot_omp │ 1       │ 24.6568  │
# │ 3   │ 11500 │ mandelbrot_omp │ 1       │ 26.997   │
# │ 4   │ 11500 │ mandelbrot_omp │ 1       │ 31.7912  │
# │ 5   │ 11500 │ mandelbrot_omp │ 1       │ 21.9735  │
# │ 6   │ 11500 │ mandelbrot_omp │ 1       │ 19.3082  │
# │ 7   │ 11500 │ mandelbrot_omp │ 1       │ 18.2148  │
# │ 8   │ 11500 │ mandelbrot_omp │ 1       │ 18.4757  │
# │ 9   │ 11500 │ mandelbrot_omp │ 1       │ 18.1315  │
# │ 10  │ 11500 │ mandelbrot_omp │ 1       │ 18.1463  │
# ⋮
# │ 70  │ 11500 │ mandelbrot_omp │ 64      │ 5.15608  │
# │ 71  │ 11500 │ mandelbrot_omp │ 128     │ 5.1659   │
# │ 72  │ 11500 │ mandelbrot_omp │ 128     │ 5.18775  │
# │ 73  │ 11500 │ mandelbrot_omp │ 128     │ 5.16999  │
# │ 74  │ 11500 │ mandelbrot_omp │ 128     │ 5.19384  │
# │ 75  │ 11500 │ mandelbrot_omp │ 128     │ 5.16772  │
# │ 76  │ 11500 │ mandelbrot_omp │ 128     │ 5.1846   │
# │ 77  │ 11500 │ mandelbrot_omp │ 128     │ 5.17818  │
# │ 78  │ 11500 │ mandelbrot_omp │ 128     │ 5.15785  │
# │ 79  │ 11500 │ mandelbrot_omp │ 128     │ 5.2009   │
# │ 80  │ 11500 │ mandelbrot_omp │ 128     │ 5.18701  │

# %% [markdown]
# Veja no gráfico:

# %%
plot_results_thread(results.threads,
    results.duration,    
    "Duration",
    max_thread_power = 7)

# %%
plot_results_thread(parsed_results.threads,
    parsed_results.mean_duration,
    "Mean Duration + CI",
    yerror = parsed_results.ci_duration,
    max_thread_power = 7)

# %% [markdown]
# Agora variando no tamanho da imagem.

# %%
threads = 4
file = "mandelbrot_omp"
size = [x for x in 1500:1000:11500]
repetitions = 10

results = run_experiments(size, file, threads, repetitions)
parsed_results = parse_results_sizes(results)

save_csv_results(results, "results_omp_s.csv")
results_omp_s = read_csv_results("results_omp_s.csv")
# Out:
# make: Nothing to be done for 'all'.
# 110×4 DataFrame
# │ Row │ size  │ file           │ threads │ duration │
# │     │ Int64 │ String         │ Int64   │ Float64  │
# ├─────┼───────┼────────────────┼─────────┼──────────┤
# │ 1   │ 1500  │ mandelbrot_omp │ 4       │ 0.104902 │
# │ 2   │ 1500  │ mandelbrot_omp │ 4       │ 0.122273 │
# │ 3   │ 1500  │ mandelbrot_omp │ 4       │ 0.131957 │
# │ 4   │ 1500  │ mandelbrot_omp │ 4       │ 0.156091 │
# │ 5   │ 1500  │ mandelbrot_omp │ 4       │ 0.127413 │
# │ 6   │ 1500  │ mandelbrot_omp │ 4       │ 0.123093 │
# │ 7   │ 1500  │ mandelbrot_omp │ 4       │ 0.119876 │
# │ 8   │ 1500  │ mandelbrot_omp │ 4       │ 0.134293 │
# │ 9   │ 1500  │ mandelbrot_omp │ 4       │ 0.140181 │
# │ 10  │ 1500  │ mandelbrot_omp │ 4       │ 0.151555 │
# ⋮
# │ 100 │ 10500 │ mandelbrot_omp │ 4       │ 5.9433   │
# │ 101 │ 11500 │ mandelbrot_omp │ 4       │ 7.5677   │
# │ 102 │ 11500 │ mandelbrot_omp │ 4       │ 7.31036  │
# │ 103 │ 11500 │ mandelbrot_omp │ 4       │ 19.5968  │
# │ 104 │ 11500 │ mandelbrot_omp │ 4       │ 9.48218  │
# │ 105 │ 11500 │ mandelbrot_omp │ 4       │ 8.31696  │
# │ 106 │ 11500 │ mandelbrot_omp │ 4       │ 7.54782  │
# │ 107 │ 11500 │ mandelbrot_omp │ 4       │ 9.69319  │
# │ 108 │ 11500 │ mandelbrot_omp │ 4       │ 7.33625  │
# │ 109 │ 11500 │ mandelbrot_omp │ 4       │ 7.51365  │
# │ 110 │ 11500 │ mandelbrot_omp │ 4       │ 7.63668  │

# %% [markdown]
# Veja no gráfico:

# %%
plot_results_size(results.size,
    results.duration,    
    "Duration",
    min_size = 1500,
    max_size = 11500,
    step = 1000)

# %%
plot_results_size(parsed_results.size,
    parsed_results.mean_duration,    
    "Mean Duration + CI",
    yerror = parsed_results.ci_duration,
    min_size = 1500,
    max_size = 11500,
    step = 1000)

# %% [markdown]
# ## Discussão
#
# ### Comportamento conforme as variações
#
# **O tamanho da entrada**
# O tempo de execução do programa cresce de forma quadrática quando se aumenta o tamanho da entrada, pois é necessario rodar o método NxN vezes, sendo N o tamanho da entrada. E isso acontece nos 3 casos (sequencial, Pthreads, OpenMP) já que isso depende do método de Mandelbrot.
#
# **O número de threads**
# Tanto utilizando Pthreads quanto OpenMP, é possível observar que com o aumento do número de threads existe uma diminuição do tempo de execução do programa. No entanto, a partir de certo ponto o overhead operacional supera o ganho da paralelização.
#
# ### Operações I/O e alocação de memória
# O impacto das operações de I/O e alocação de memória no tempo de execução deveria se mostrar mais significativo no OpenMP porque elas são feitas de forma implícita, de modo que a medição de tempo não pode desconsiderá-las. Surpreendentemente, o tempo do programa se mantém mais ou menos parecido (utilizando o mesmo número de threads) no Pthreads e no OpenMP. Supomos que isso ocorre porque o OpenMP deve conter uma série de otimizações que permite compensar o overhead.
#
# ### Perguntas interessantes
# **Por que o tempo continua diminuindo mesmo após superar o número de núcleos do computador (com Pthreads)?**
# Isso se dá devido ao modo como o sistema operacional gerencia o tempo de execução de cada processo. O paralelismo simulado com concorrência, permite que, mesmo com o número de threads superando o número de núcleos, a eficiência do programa continue aumentando.
